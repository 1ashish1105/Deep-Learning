# %% [markdown]
# <a href="https://colab.research.google.com/github/1ashish1105/Deep-Learning/blob/main/Data_Augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
# !ls /content
# Out:
# aug  sample_data

# %%
# !find / -name "cat.jpg" 2>/dev/null
# Out:
# /cat.jpg

# %%
img = image.load_img('/cat.jpg', target_size=(200,200))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
datagen=ImageDataGenerator(
    rotation_range=30,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.2,
    height_shift_range=0.2,
    fill_mode='constant'
)

# %%
img=image.img_to_array(img)

# %%
img.shape
# Out:
# (200, 200, 3)

# %%
input_batch=img.reshape(1,200,200,3)

# %%
import os

os.makedirs("aug", exist_ok=True)

# %%
i=0
for output in datagen.flow(input_batch,batch_size=1,save_to_dir='aug'):
  i=i+1
  if(i==10):
    break

# %%
input_batch.shape
# Out:
# (1, 200, 200, 3)

# %%
import os

print(os.path.exists("aug"))
# Out:
# True
